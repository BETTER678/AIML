# %% [markdown]
# #What is a Tuple?
# A Tuple in Python is a collection of multiple values stored in a single variable, just like a list, but the main difference is:
#
# Tuple is immutable once created, you cannot change its elements.
